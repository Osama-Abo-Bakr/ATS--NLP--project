# %% [markdown]
# # Loading Library

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from IPython import display
from roboflow import Roboflow
from ultralytics import YOLO

display.clear_output()
from IPython.display import display, Image

# %% [markdown]
# # Loading Data

# %% [markdown]
# # https://universe.roboflow.com/myworkspace-8qrsb/resume-section-azjq9

# %%
rf = Roboflow(api_key="A0JN8vO130atlzhwM2JN")
project = rf.workspace("myworkspace-8qrsb").project("resume-section-azjq9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Resume-section-1 in yolov11:: 100%|██████████| 3364/3364 [00:01<00:00, 3073.58it/s]

# %% [markdown]
# # Train The Model

# %%
model = YOLO('yolo11s.pt')

# Train the model
model.train(data="/content/Resume-section-1/data.yaml", epochs=50, batch=16)
# Out:
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Evaluation Model

# %%
model.val(data='/content/Resume-section-1/data.yaml')
# Out:
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,418,218 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1144.3±424.1 MB/s, size: 52.3 KB)
# val: Scanning /content/Resume-section-1/valid/labels.cache... 167 images, 0 backgrounds, 0 corrupt: 100%|██████████| 167/167 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.42it/s]
#                    all        167       1144      0.719      0.647      0.684      0.558
#            Achievement          5          5          1          0     0.0967      0.087
#         Certifications         23         24      0.274      0.375      0.241      0.207
#              Community         20         20      0.563      0.324      0.417      0.371
#                Contact        129        136      0.757      0.809      0.853      0.648
# ...

# %%
Image(filename=f'/content/runs/detect/train2/results.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train2/val_batch2_labels.jpg', width=600)

# %% [markdown]
# ## Predictions

# %%
from PIL import Image
import numpy as np
from ultralytics import YOLO

def detect_section_in_resumes(image_path):
    model = YOLO("/content/runs/detect/train2/weights/best.pt")
    image = Image.open(image_path)
    image = np.array(image)
    w, h, _ = image.shape

    results = model.predict(image)

    # Access the results
    for result in results:
        xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
        names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
        confs = result.boxes.conf  # confidence score of each box


        print(confs)
        print(names)
        print(xyxy)

# %%
detect_section_in_resumes("/content/cv-3.png")
# Out:
# 0: 640x480 1 Contact, 1 Experience, 1 Name, 1 resume, 1 skills, 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# tensor([0.9614, 0.8993, 0.8490, 0.8166, 0.7144], device='cuda:0')
# ['Experience', 'resume', 'Name', 'Contact', 'skills']
# tensor([[ 101.5561,  722.1939, 1030.1394, 1504.3813],
#         [  98.9611,  290.4114, 1018.6663,  481.0285],
#         [ 288.7560,   97.3565,  841.2921,  161.2204],
#         [ 292.2839,  172.1175,  848.0439,  230.5766],
#         [ 127.5783,  529.4922, 1009.3903,  666.9803]], device='cuda:0')
